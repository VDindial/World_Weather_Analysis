# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ee5543d0c756aebfc41ea1e464769a99

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_data=[]

# Initialize record count and set count
record_count=1
set_count=1 

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description= city_weather ["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bobon
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | marinette
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | prince rupert
# Processing Record 10 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 1 | toamasina
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | latehar
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | luanda
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | gorontalo
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | luganville
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | tautira
# Processing Record 23 of Set 1 | chara
# Processing Record 24 of Set 1 | broome
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | katherine
# Processing Record 27 of Set 1 | burica
# City not found. Skipping...
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | flin flon
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | west bay
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | hagenow
# Processing Record 36 of Set 1 | satkhira
# Processing Record 37 of Set 1 | yatou
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | ukhta
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | rudnogorsk
# Processing Record 46 of Set 1 | kawalu
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | tuatapere
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | aklavik
# Processing Record 2 of Set 2 | murgab
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | felanitx
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | qinhuangdao
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | villefranche-de-rouergue
# Processing Record 14 of Set 2 | price
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | lompoc
# Processing Record 19 of Set 2 | half moon bay
# Processing Record 20 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 2 | zhanakorgan
# Processing Record 22 of Set 2 | mnogovershinnyy
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | lieksa
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | boueni
# Processing Record 28 of Set 2 | gambo
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | saurimo
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | cayenne
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | nakusp
# Processing Record 37 of Set 2 | puerto penasco
# Processing Record 38 of Set 2 | airai
# Processing Record 39 of Set 2 | bouna
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | walvis bay
# Processing Record 46 of Set 2 | honiara
# Processing Record 47 of Set 2 | portobelo
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | suba
# Processing Record 1 of Set 3 | shenzhen
# Processing Record 2 of Set 3 | vila velha
# Processing Record 3 of Set 3 | fairview
# Processing Record 4 of Set 3 | grand gaube
# Processing Record 5 of Set 3 | ingham
# Processing Record 6 of Set 3 | zhigalovo
# Processing Record 7 of Set 3 | kolyvan
# Processing Record 8 of Set 3 | barra do garcas
# Processing Record 9 of Set 3 | seryshevo
# Processing Record 10 of Set 3 | naze
# Processing Record 11 of Set 3 | san cristobal
# Processing Record 12 of Set 3 | sao jose da coroa grande
# Processing Record 13 of Set 3 | port-cartier
# Processing Record 14 of Set 3 | shamkhal
# Processing Record 15 of Set 3 | akyab
# Processing Record 16 of Set 3 | waipawa
# Processing Record 17 of Set 3 | svit
# Processing Record 18 of Set 3 | fare
# Processing Record 19 of Set 3 | atyrau
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | ancud
# Processing Record 22 of Set 3 | kalmunai
# Processing Record 23 of Set 3 | bandarbeyla
# Processing Record 24 of Set 3 | ornskoldsvik
# Processing Record 25 of Set 3 | maputo
# Processing Record 26 of Set 3 | hamilton
# Processing Record 27 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 29 of Set 3 | oranjemund
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | gumla
# Processing Record 32 of Set 3 | sioux lookout
# Processing Record 33 of Set 3 | sulangan
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | pangnirtung
# Processing Record 36 of Set 3 | macomb
# Processing Record 37 of Set 3 | mitsamiouli
# Processing Record 38 of Set 3 | nouadhibou
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | gravdal
# Processing Record 41 of Set 3 | abha
# Processing Record 42 of Set 3 | pontianak
# Processing Record 43 of Set 3 | grindavik
# Processing Record 44 of Set 3 | dubbo
# Processing Record 45 of Set 3 | calabozo
# Processing Record 46 of Set 3 | san francisco del mar
# Processing Record 47 of Set 3 | kourou
# Processing Record 48 of Set 3 | filadelfia
# Processing Record 49 of Set 3 | leshan
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | gimli
# Processing Record 7 of Set 4 | coquimbo
# Processing Record 8 of Set 4 | peno
# Processing Record 9 of Set 4 | nabire
# Processing Record 10 of Set 4 | champerico
# Processing Record 11 of Set 4 | pochutla
# Processing Record 12 of Set 4 | leshukonskoye
# Processing Record 13 of Set 4 | ifanadiana
# Processing Record 14 of Set 4 | provost
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | castro
# Processing Record 17 of Set 4 | la ronge
# Processing Record 18 of Set 4 | talnakh
# Processing Record 19 of Set 4 | berlevag
# Processing Record 20 of Set 4 | bahia de caraquez
# Processing Record 21 of Set 4 | cherskiy
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | canavieiras
# Processing Record 24 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 4 | cabo san lucas
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | arraial do cabo
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | along
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | belmonte
# Processing Record 32 of Set 4 | kruisfontein
# Processing Record 33 of Set 4 | pevek
# Processing Record 34 of Set 4 | hermanus
# Processing Record 35 of Set 4 | kendari
# Processing Record 36 of Set 4 | bosaso
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | kyren
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | diffa
# Processing Record 44 of Set 4 | husavik
# Processing Record 45 of Set 4 | alta floresta
# Processing Record 46 of Set 4 | sonamura
# Processing Record 47 of Set 4 | batagay-alyta
# Processing Record 48 of Set 4 | tezu
# Processing Record 49 of Set 4 | timra
# Processing Record 50 of Set 4 | hammond
# Processing Record 1 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | krasnyy oktyabr
# Processing Record 4 of Set 5 | povenets
# Processing Record 5 of Set 5 | port shepstone
# Processing Record 6 of Set 5 | troitskoye
# Processing Record 7 of Set 5 | berdigestyakh
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | kayerkan
# Processing Record 10 of Set 5 | ribeira grande
# Processing Record 11 of Set 5 | nikolskoye
# Processing Record 12 of Set 5 | sitka
# Processing Record 13 of Set 5 | tocopilla
# Processing Record 14 of Set 5 | manzil salim
# Processing Record 15 of Set 5 | souillac
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | carutapera
# Processing Record 18 of Set 5 | kieta
# Processing Record 19 of Set 5 | lethem
# Processing Record 20 of Set 5 | flinders
# Processing Record 21 of Set 5 | puerto baquerizo moreno
# Processing Record 22 of Set 5 | bredasdorp
# Processing Record 23 of Set 5 | santa cruz
# Processing Record 24 of Set 5 | north bend
# Processing Record 25 of Set 5 | vapnyarka
# Processing Record 26 of Set 5 | cap malheureux
# Processing Record 27 of Set 5 | susanville
# Processing Record 28 of Set 5 | penzance
# Processing Record 29 of Set 5 | wunsiedel
# Processing Record 30 of Set 5 | barghat
# Processing Record 31 of Set 5 | abu dhabi
# Processing Record 32 of Set 5 | tazovskiy
# Processing Record 33 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 34 of Set 5 | pervomayskoye
# Processing Record 35 of Set 5 | butaritari
# Processing Record 36 of Set 5 | galeana
# Processing Record 37 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 5 | shingu
# Processing Record 39 of Set 5 | noyabrsk
# Processing Record 40 of Set 5 | port macquarie
# Processing Record 41 of Set 5 | gonbad-e qabus
# Processing Record 42 of Set 5 | roald
# Processing Record 43 of Set 5 | selma
# Processing Record 44 of Set 5 | warrington
# Processing Record 45 of Set 5 | klaksvik
# Processing Record 46 of Set 5 | the valley
# Processing Record 47 of Set 5 | poddorye
# Processing Record 48 of Set 5 | sisimiut
# Processing Record 49 of Set 5 | wasilla
# Processing Record 50 of Set 5 | coahuayana
# Processing Record 1 of Set 6 | paita
# Processing Record 2 of Set 6 | dikson
# Processing Record 3 of Set 6 | urumqi
# Processing Record 4 of Set 6 | inuvik
# Processing Record 5 of Set 6 | los llanos de aridane
# Processing Record 6 of Set 6 | ruteng
# Processing Record 7 of Set 6 | kerch
# Processing Record 8 of Set 6 | da nang
# Processing Record 9 of Set 6 | tezpur
# Processing Record 10 of Set 6 | khatanga
# Processing Record 11 of Set 6 | benguela
# Processing Record 12 of Set 6 | troitsko-pechorsk
# Processing Record 13 of Set 6 | rocha
# Processing Record 14 of Set 6 | pacific grove
# Processing Record 15 of Set 6 | hauterive
# Processing Record 16 of Set 6 | kutum
# Processing Record 17 of Set 6 | whitehorse
# Processing Record 18 of Set 6 | tawang
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | springfield
# Processing Record 21 of Set 6 | acapulco
# Processing Record 22 of Set 6 | yulara
# Processing Record 23 of Set 6 | greytown
# Processing Record 24 of Set 6 | salinas
# Processing Record 25 of Set 6 | tamale
# Processing Record 26 of Set 6 | shache
# Processing Record 27 of Set 6 | zhigansk
# Processing Record 28 of Set 6 | anchorage
# Processing Record 29 of Set 6 | tucson
# Processing Record 30 of Set 6 | baykit
# Processing Record 31 of Set 6 | lavrentiya
# Processing Record 32 of Set 6 | hastings
# Processing Record 33 of Set 6 | nome
# Processing Record 34 of Set 6 | cururupu
# Processing Record 35 of Set 6 | san patricio
# Processing Record 36 of Set 6 | merauke
# Processing Record 37 of Set 6 | east london
# Processing Record 38 of Set 6 | kohat
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | majene
# Processing Record 41 of Set 6 | vostok
# Processing Record 42 of Set 6 | campbellsville
# Processing Record 43 of Set 6 | sorland
# Processing Record 44 of Set 6 | bandiagara
# Processing Record 45 of Set 6 | arak
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | zyryanka
# Processing Record 48 of Set 6 | davila
# Processing Record 49 of Set 6 | nuevitas
# Processing Record 50 of Set 6 | necochea
# Processing Record 1 of Set 7 | portland
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | haines junction
# Processing Record 4 of Set 7 | nantucket
# Processing Record 5 of Set 7 | redcliffe
# Processing Record 6 of Set 7 | quelimane
# Processing Record 7 of Set 7 | dongsheng
# Processing Record 8 of Set 7 | santa marta
# Processing Record 9 of Set 7 | omsukchan
# Processing Record 10 of Set 7 | matagami
# Processing Record 11 of Set 7 | otradnoye
# Processing Record 12 of Set 7 | tigil
# Processing Record 13 of Set 7 | calvia
# Processing Record 14 of Set 7 | bilma
# Processing Record 15 of Set 7 | tura
# Processing Record 16 of Set 7 | ossora
# Processing Record 17 of Set 7 | mount isa
# Processing Record 18 of Set 7 | jiuquan
# Processing Record 19 of Set 7 | kirakira
# Processing Record 20 of Set 7 | salta
# Processing Record 21 of Set 7 | oda
# Processing Record 22 of Set 7 | omboue
# Processing Record 23 of Set 7 | piacabucu
# Processing Record 24 of Set 7 | tevaitoa
# Processing Record 25 of Set 7 | oriximina
# Processing Record 26 of Set 7 | sao filipe
# Processing Record 27 of Set 7 | sancti spiritus
# Processing Record 28 of Set 7 | suhut
# Processing Record 29 of Set 7 | surt
# Processing Record 30 of Set 7 | celestun
# Processing Record 31 of Set 7 | morehead
# Processing Record 32 of Set 7 | sao joao da barra
# Processing Record 33 of Set 7 | kazachinskoye
# Processing Record 34 of Set 7 | maniitsoq
# Processing Record 35 of Set 7 | eyl
# Processing Record 36 of Set 7 | katsuura
# Processing Record 37 of Set 7 | kallaste
# Processing Record 38 of Set 7 | mikuni
# Processing Record 39 of Set 7 | chuy
# Processing Record 40 of Set 7 | pangai
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | seydi
# Processing Record 43 of Set 7 | provideniya
# Processing Record 44 of Set 7 | tabuk
# Processing Record 45 of Set 7 | khristoforovo
# City not found. Skipping...
# Processing Record 46 of Set 7 | namatanai
# Processing Record 47 of Set 7 | ikwiriri
# Processing Record 48 of Set 7 | yar-sale
# Processing Record 49 of Set 7 | warri
# Processing Record 50 of Set 7 | vanimo
# Processing Record 1 of Set 8 | vanavara
# Processing Record 2 of Set 8 | sortavala
# Processing Record 3 of Set 8 | ongandjera
# Processing Record 4 of Set 8 | anadyr
# Processing Record 5 of Set 8 | khandyga
# Processing Record 6 of Set 8 | havelock
# Processing Record 7 of Set 8 | gavle
# Processing Record 8 of Set 8 | bend
# Processing Record 9 of Set 8 | boende
# Processing Record 10 of Set 8 | buraydah
# Processing Record 11 of Set 8 | tiarei
# Processing Record 12 of Set 8 | axim
# Processing Record 13 of Set 8 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 14 of Set 8 | kamaishi
# Processing Record 15 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 8 | mardin
# Processing Record 17 of Set 8 | shimoda
# Processing Record 18 of Set 8 | aksu
# Processing Record 19 of Set 8 | puerto escondido
# Processing Record 20 of Set 8 | san borja
# Processing Record 21 of Set 8 | poum
# Processing Record 22 of Set 8 | ahipara
# Processing Record 23 of Set 8 | ponta delgada
# Processing Record 24 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 8 | harper
# Processing Record 26 of Set 8 | taybad
# Processing Record 27 of Set 8 | sangar
# Processing Record 28 of Set 8 | shebunino
# Processing Record 29 of Set 8 | lagoa
# Processing Record 30 of Set 8 | basco
# Processing Record 31 of Set 8 | sonoita
# Processing Record 32 of Set 8 | russell
# Processing Record 33 of Set 8 | kahului
# Processing Record 34 of Set 8 | karwar
# Processing Record 35 of Set 8 | beringovskiy
# Processing Record 36 of Set 8 | mayo
# Processing Record 37 of Set 8 | altay
# Processing Record 38 of Set 8 | lai
# Processing Record 39 of Set 8 | champoton
# Processing Record 40 of Set 8 | chegdomyn
# Processing Record 41 of Set 8 | ladson
# Processing Record 42 of Set 8 | lorengau
# Processing Record 43 of Set 8 | cristalina
# Processing Record 44 of Set 8 | makakilo city
# Processing Record 45 of Set 8 | filingue
# Processing Record 46 of Set 8 | oga
# Processing Record 47 of Set 8 | bilibino
# Processing Record 48 of Set 8 | kuala terengganu
# Processing Record 49 of Set 8 | gamboula
# Processing Record 50 of Set 8 | pekan
# Processing Record 1 of Set 9 | asau
# Processing Record 2 of Set 9 | zatoka
# Processing Record 3 of Set 9 | manta
# Processing Record 4 of Set 9 | jundubah
# City not found. Skipping...
# Processing Record 5 of Set 9 | maragogi
# Processing Record 6 of Set 9 | gazojak
# Processing Record 7 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 8 of Set 9 | evensk
# Processing Record 9 of Set 9 | beyneu
# Processing Record 10 of Set 9 | camacha
# Processing Record 11 of Set 9 | huilong
# Processing Record 12 of Set 9 | alofi
# Processing Record 13 of Set 9 | rocky mountain house
# Processing Record 14 of Set 9 | muros
# Processing Record 15 of Set 9 | batemans bay
# Processing Record 16 of Set 9 | gafanha da encarnacao
# Processing Record 17 of Set 9 | saint anthony
# Processing Record 18 of Set 9 | svetlaya
# Processing Record 19 of Set 9 | maridi
# Processing Record 20 of Set 9 | san juan de uraba
# Processing Record 21 of Set 9 | bathsheba
# Processing Record 22 of Set 9 | leua
# Processing Record 23 of Set 9 | hambantota
# Processing Record 24 of Set 9 | leningradskiy
# Processing Record 25 of Set 9 | atar
# Processing Record 26 of Set 9 | luderitz
# Processing Record 27 of Set 9 | narsaq
# Processing Record 28 of Set 9 | te karaka
# Processing Record 29 of Set 9 | nara
# Processing Record 30 of Set 9 | bitung
# Processing Record 31 of Set 9 | bulaevo
# Processing Record 32 of Set 9 | semey
# Processing Record 33 of Set 9 | itupiranga
# Processing Record 34 of Set 9 | varhaug
# Processing Record 35 of Set 9 | olafsvik
# Processing Record 36 of Set 9 | port hardy
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | gueret
# Processing Record 39 of Set 9 | namibe
# Processing Record 40 of Set 9 | ixtapa
# Processing Record 41 of Set 9 | puerto carreno
# Processing Record 42 of Set 9 | havre
# Processing Record 43 of Set 9 | vorozhba
# Processing Record 44 of Set 9 | gigmoto
# Processing Record 45 of Set 9 | brae
# Processing Record 46 of Set 9 | marang
# Processing Record 47 of Set 9 | mana
# Processing Record 48 of Set 9 | mutoko
# Processing Record 49 of Set 9 | inhambane
# Processing Record 50 of Set 9 | san rafael del sur
# Processing Record 1 of Set 10 | kavieng
# Processing Record 2 of Set 10 | saldanha
# Processing Record 3 of Set 10 | daru
# Processing Record 4 of Set 10 | mehamn
# Processing Record 5 of Set 10 | zhezkazgan
# Processing Record 6 of Set 10 | el alto
# Processing Record 7 of Set 10 | bintulu
# Processing Record 8 of Set 10 | kyra
# Processing Record 9 of Set 10 | viedma
# Processing Record 10 of Set 10 | erzurum
# Processing Record 11 of Set 10 | iracoubo
# Processing Record 12 of Set 10 | swan river
# Processing Record 13 of Set 10 | port hedland
# Processing Record 14 of Set 10 | panlaitan
# Processing Record 15 of Set 10 | san luis
# Processing Record 16 of Set 10 | almansa
# Processing Record 17 of Set 10 | olinda
# Processing Record 18 of Set 10 | hofn
# Processing Record 19 of Set 10 | margate
# Processing Record 20 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 10 | bukene
# Processing Record 22 of Set 10 | netarhat
# Processing Record 23 of Set 10 | lasa
# Processing Record 24 of Set 10 | malakal
# Processing Record 25 of Set 10 | dalvik
# Processing Record 26 of Set 10 | aksarka
# Processing Record 27 of Set 10 | morant bay
# Processing Record 28 of Set 10 | taltal
# Processing Record 29 of Set 10 | cape coast
# Processing Record 30 of Set 10 | kapit
# Processing Record 31 of Set 10 | coolum beach
# Processing Record 32 of Set 10 | tuy hoa
# Processing Record 33 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 10 | coos bay
# Processing Record 35 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 10 | preobrazheniye
# Processing Record 37 of Set 10 | pozo colorado
# Processing Record 38 of Set 10 | agva
# City not found. Skipping...
# Processing Record 39 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 10 | cananeia
# Processing Record 41 of Set 10 | mailsi
# Processing Record 42 of Set 10 | izumo
# Processing Record 43 of Set 10 | dhana
# Processing Record 44 of Set 10 | bubaque
# Processing Record 45 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 46 of Set 10 | leh
# Processing Record 47 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 10 | jizan
# Processing Record 49 of Set 10 | swiecie
# Processing Record 50 of Set 10 | kachiry
# Processing Record 1 of Set 11 | umkomaas
# Processing Record 2 of Set 11 | hobyo
# Processing Record 3 of Set 11 | pokaran
# Processing Record 4 of Set 11 | inta
# Processing Record 5 of Set 11 | wasserburg
# Processing Record 6 of Set 11 | kardla
# Processing Record 7 of Set 11 | george
# Processing Record 8 of Set 11 | yingkou
# Processing Record 9 of Set 11 | vestmanna
# Processing Record 10 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 11 | arawa
# Processing Record 12 of Set 11 | pisco
# Processing Record 13 of Set 11 | puerto colombia
# Processing Record 14 of Set 11 | pervomayskiy
# Processing Record 15 of Set 11 | atbasar
# Processing Record 16 of Set 11 | minturno
# Processing Record 17 of Set 11 | poshekhonye
# Processing Record 18 of Set 11 | comodoro rivadavia
# Processing Record 19 of Set 11 | moree
# Processing Record 20 of Set 11 | rabo de peixe
# Processing Record 21 of Set 11 | gamba
# Processing Record 22 of Set 11 | awbari
# Processing Record 23 of Set 11 | bozeman
# Processing Record 24 of Set 11 | novouzensk
# Processing Record 25 of Set 11 | imeni poliny osipenko
# Processing Record 26 of Set 11 | devesel
# Processing Record 27 of Set 11 | kumluca
# Processing Record 28 of Set 11 | winnemucca
# Processing Record 29 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 30 of Set 11 | lagunas
# Processing Record 31 of Set 11 | pundri
# Processing Record 32 of Set 11 | puerto ayacucho
# Processing Record 33 of Set 11 | dunedin
# Processing Record 34 of Set 11 | kavaratti
# Processing Record 35 of Set 11 | terrace
# Processing Record 36 of Set 11 | abnub
# Processing Record 37 of Set 11 | aban
# Processing Record 38 of Set 11 | simcoe
# Processing Record 39 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 40 of Set 11 | batagay
# Processing Record 41 of Set 11 | lodja
# Processing Record 42 of Set 11 | santa luzia
# Processing Record 43 of Set 11 | sao gabriel da cachoeira
# Processing Record 44 of Set 11 | moctezuma
# Processing Record 45 of Set 11 | touros
# Processing Record 46 of Set 11 | mount gambier
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | nishihara
# Processing Record 49 of Set 11 | fonte boa
# Processing Record 50 of Set 11 | dezhou
# Processing Record 1 of Set 12 | guerrero negro
# Processing Record 2 of Set 12 | pimenta bueno
# Processing Record 3 of Set 12 | oleksandrivka
# Processing Record 4 of Set 12 | barsovo
# Processing Record 5 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 12 | letlhakane
# Processing Record 7 of Set 12 | ballangen
# Processing Record 8 of Set 12 | sinnamary
# Processing Record 9 of Set 12 | rawson
# Processing Record 10 of Set 12 | imperia
# Processing Record 11 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 12 | vestmannaeyjar
# Processing Record 13 of Set 12 | moranbah
# Processing Record 14 of Set 12 | khakhea
# Processing Record 15 of Set 12 | chik
# Processing Record 16 of Set 12 | manokwari
# Processing Record 17 of Set 12 | itaituba
# Processing Record 18 of Set 12 | fort nelson
# Processing Record 19 of Set 12 | shuya
# Processing Record 20 of Set 12 | avera
# Processing Record 21 of Set 12 | mayskiy
# Processing Record 22 of Set 12 | tignere
# Processing Record 23 of Set 12 | hede
# Processing Record 24 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 12 | nkan
# Processing Record 26 of Set 12 | raudeberg
# Processing Record 27 of Set 12 | burnie
# Processing Record 28 of Set 12 | qasigiannguit
# Processing Record 29 of Set 12 | alekseyevka
# Processing Record 30 of Set 12 | le port
# Processing Record 31 of Set 12 | lata
# Processing Record 32 of Set 12 | iquitos
# Processing Record 33 of Set 12 | mhango
# Processing Record 34 of Set 12 | binga
# Processing Record 35 of Set 12 | tessalit
# Processing Record 36 of Set 12 | san luis de la paz
# Processing Record 37 of Set 12 | sovetskiy
# Processing Record 38 of Set 12 | barra dos coqueiros
# Processing Record 39 of Set 12 | vilyuysk
# Processing Record 40 of Set 12 | gillette
# Processing Record 41 of Set 12 | scranton
# Processing Record 42 of Set 12 | sokolo
# Processing Record 43 of Set 12 | meiganga
# Processing Record 44 of Set 12 | trincomalee
# Processing Record 45 of Set 12 | slavyanka
# Processing Record 46 of Set 12 | marathon
# Processing Record 47 of Set 12 | lianzhou
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | ust-nera
# Processing Record 50 of Set 12 | smithers
# Processing Record 1 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 13 | cortland
# Processing Record 3 of Set 13 | pontes e lacerda
# Processing Record 4 of Set 13 | marsa matruh
# Processing Record 5 of Set 13 | sirnach
# Processing Record 6 of Set 13 | san policarpo
# Processing Record 7 of Set 13 | pavlodar
# Processing Record 8 of Set 13 | yataity del norte
# Processing Record 9 of Set 13 | clarksburg
# Processing Record 10 of Set 13 | jiutai
# Processing Record 11 of Set 13 | nichinan
# Processing Record 12 of Set 13 | casas grandes
# Processing Record 13 of Set 13 | hammerfest
# Processing Record 14 of Set 13 | amposta
# Processing Record 15 of Set 13 | singkang
# Processing Record 16 of Set 13 | goderich
# Processing Record 17 of Set 13 | siverek
# Processing Record 18 of Set 13 | atambua
# Processing Record 19 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 20 of Set 13 | cumpas
# Processing Record 21 of Set 13 | canico
# Processing Record 22 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 13 | artvin
# Processing Record 24 of Set 13 | sasaguri
# Processing Record 25 of Set 13 | upata
# Processing Record 26 of Set 13 | maneadero
# Processing Record 27 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 13 | namie
# Processing Record 29 of Set 13 | belem de sao francisco
# Processing Record 30 of Set 13 | pokhara
# Processing Record 31 of Set 13 | uruguaiana
# Processing Record 32 of Set 13 | richards bay
# Processing Record 33 of Set 13 | galle
# Processing Record 34 of Set 13 | las vegas
# Processing Record 35 of Set 13 | beloha
# Processing Record 36 of Set 13 | kaitangata
# Processing Record 37 of Set 13 | kattivakkam
# Processing Record 38 of Set 13 | bacalar
# Processing Record 39 of Set 13 | qena
# Processing Record 40 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 13 | ayagoz
# Processing Record 42 of Set 13 | xining
# Processing Record 43 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 13 | esperance
# Processing Record 45 of Set 13 | msanga
# Processing Record 46 of Set 13 | antalaha
# Processing Record 47 of Set 13 | polunochnoye
# Processing Record 48 of Set 13 | amuntai
# Processing Record 49 of Set 13 | okhotsk
# Processing Record 50 of Set 13 | odweyne
# Processing Record 1 of Set 14 | kailua
# Processing Record 2 of Set 14 | sivas
# Processing Record 3 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 14 | chicama
# Processing Record 5 of Set 14 | remanso
# Processing Record 6 of Set 14 | launceston
# Processing Record 7 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 14 | nyazepetrovsk
# Processing Record 9 of Set 14 | parrita
# Processing Record 10 of Set 14 | narayanganj
# Processing Record 11 of Set 14 | sistranda
# Processing Record 12 of Set 14 | stanger
# Processing Record 13 of Set 14 | oktyabrskoye
# Processing Record 14 of Set 14 | volnovakha
# Processing Record 15 of Set 14 | caravelas
# Processing Record 16 of Set 14 | coria
# Processing Record 17 of Set 14 | bokhan
# Processing Record 18 of Set 14 | velikie luki
# City not found. Skipping...
# Processing Record 19 of Set 14 | manggar
# Processing Record 20 of Set 14 | mayya
# Processing Record 21 of Set 14 | scarborough
# Processing Record 22 of Set 14 | huarmey
# Processing Record 23 of Set 14 | santa rosalia
# Processing Record 24 of Set 14 | klyuchi
# Processing Record 25 of Set 14 | mandalgovi
# Processing Record 26 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 14 | pocoes
# Processing Record 28 of Set 14 | raul soares
# Processing Record 29 of Set 14 | guangzhou
# Processing Record 30 of Set 14 | darhan
# Processing Record 31 of Set 14 | engen
# Processing Record 32 of Set 14 | santa isabel do rio negro
# Processing Record 33 of Set 14 | baghdad
# Processing Record 34 of Set 14 | bloemfontein
# Processing Record 35 of Set 14 | bela
# Processing Record 36 of Set 14 | saint-georges
# Processing Record 37 of Set 14 | sao domingos do maranhao
# Processing Record 38 of Set 14 | yumen
# Processing Record 39 of Set 14 | nurota
# Processing Record 40 of Set 14 | san jose
# Processing Record 41 of Set 14 | muroto
# Processing Record 42 of Set 14 | taupo
# Processing Record 43 of Set 14 | bar harbor
# Processing Record 44 of Set 14 | kresek
# Processing Record 45 of Set 14 | galveston
# Processing Record 46 of Set 14 | san francisco
# Processing Record 47 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 14 | port blair
# Processing Record 49 of Set 14 | mianyang
# Processing Record 50 of Set 14 | hirara
# Processing Record 1 of Set 15 | puerto madryn
# Processing Record 2 of Set 15 | borovskoy
# Processing Record 3 of Set 15 | abapo
# Processing Record 4 of Set 15 | tumpat
# Processing Record 5 of Set 15 | reshetnikovo
# Processing Record 6 of Set 15 | manakara
# Processing Record 7 of Set 15 | biak
# Processing Record 8 of Set 15 | labuhan
# Processing Record 9 of Set 15 | salinopolis
# Processing Record 10 of Set 15 | arkhara
# Processing Record 11 of Set 15 | mazyr
# Processing Record 12 of Set 15 | gondanglegi
# Processing Record 13 of Set 15 | puerto cabezas
# Processing Record 14 of Set 15 | decatur
# Processing Record 15 of Set 15 | tonj
# Processing Record 16 of Set 15 | yenagoa
# Processing Record 17 of Set 15 | nizwa
# Processing Record 18 of Set 15 | krasnyy chikoy
# Processing Record 19 of Set 15 | demyansk
# Processing Record 20 of Set 15 | dinar
# Processing Record 21 of Set 15 | masindi
# Processing Record 22 of Set 15 | korla
# Processing Record 23 of Set 15 | aswan
# Processing Record 24 of Set 15 | nouakchott
# Processing Record 25 of Set 15 | amapa
# Processing Record 26 of Set 15 | cockburn town
# Processing Record 27 of Set 15 | antofagasta
# Processing Record 28 of Set 15 | nizhneangarsk
# Processing Record 29 of Set 15 | coihueco
# Processing Record 30 of Set 15 | skibbereen
# Processing Record 31 of Set 15 | cape elizabeth
# City not found. Skipping...
# Processing Record 32 of Set 15 | hualmay
# Processing Record 33 of Set 15 | lebedyn
# Processing Record 34 of Set 15 | doha
# Processing Record 35 of Set 15 | magadan
# Processing Record 36 of Set 15 | shwebo
# Processing Record 37 of Set 15 | banjar
# Processing Record 38 of Set 15 | nizhniy lomov
# Processing Record 39 of Set 15 | roseto degli abruzzi
# Processing Record 40 of Set 15 | muravlenko
# Processing Record 41 of Set 15 | tortoli
# Processing Record 42 of Set 15 | chipinge
# Processing Record 43 of Set 15 | vredendal
# Processing Record 44 of Set 15 | skagen
# Processing Record 45 of Set 15 | kaeo
# Processing Record 46 of Set 15 | sarakhs
# Processing Record 47 of Set 15 | sagopshi
# Processing Record 48 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 15 | severo-yeniseyskiy
# Processing Record 50 of Set 15 | hovd
# Processing Record 1 of Set 16 | sungaipenuh
# Processing Record 2 of Set 16 | bankja
# City not found. Skipping...
# Processing Record 3 of Set 16 | nanortalik
# Processing Record 4 of Set 16 | galdar
# Processing Record 5 of Set 16 | tuburan
# Processing Record 6 of Set 16 | kaniama
# Processing Record 7 of Set 16 | egvekinot
# Processing Record 8 of Set 16 | villa maria
# Processing Record 9 of Set 16 | pokhvistnevo
# Processing Record 10 of Set 16 | port lincoln
# Processing Record 11 of Set 16 | ca mau
# Processing Record 12 of Set 16 | dibaya
# City not found. Skipping...
# Processing Record 13 of Set 16 | burns lake
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Bobon  12.52  124.56     76.50        91          88        4.34
# 1   Chokurdakh  70.63  147.92    -14.55        90          74        3.83
# 2    Marinette  45.10  -87.63     51.80        57           1       11.41
# 3    Busselton -33.65  115.33     60.01        84           9        7.78
# 4  Port Alfred -33.59   26.89     66.74        82           1       24.72
#
#        Description
# 0  overcast clouds
# 1    broken clouds
# 2        clear sky
# 3        clear sky
# 4        clear sky

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
